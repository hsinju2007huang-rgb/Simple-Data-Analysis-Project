# %%
import pandas as pd

grades=pd.read_csv('C:\\Users\\USER\\Downloads\\ultimate_student_productivity_dataset_5000.csv')

print(grades.to_string())
# Out:
#       student_id  age  gender academic_level  study_hours  self_study_hours  online_classes_hours  social_media_hours  gaming_hours  sleep_hours  screen_time_hours  exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline internet_quality  mental_health_score  focus_index  burnout_level  productivity_score  exam_score
# 0              1   18   Other    High School         7.64              1.56                  2.20                3.05          2.19         6.52               6.47                81                  38              1                  0             Good                   10        43.05          31.77               73.65       50.16
# ...

# %%
grades.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
grades.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   str
#  3   academic_level        5000 non-null   str
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
# ...

# %%
#filter non-numerical columns as well as complicated columns with data to analyze correlation
columns_to_drop = ['student_id', 'gender', 'academic_level', 'internet_quality', 'gaming_hours', 'part_time_job', 'upcoming_deadline', 'social_media_hours','exercise_minutes']
grades = grades.drop(columns=columns_to_drop)
print(grades.to_string())
# Out:
#       age  study_hours  self_study_hours  online_classes_hours  sleep_hours  screen_time_hours  caffeine_intake_mg  mental_health_score  focus_index  burnout_level  productivity_score  exam_score
# 0      18         7.64              1.56                  2.20         6.52               6.47                  38                   10        43.05          31.77               73.65       50.16
# 1      18         2.21              2.22                  2.10         5.97               6.05                 339                    3        15.92          37.00               13.70        1.00
# 2      22         3.45              0.00                  0.29         8.39               7.62                 266                    8        27.39          34.37               45.15       18.30
# 3      17         5.75              2.08                  3.01         6.31              11.67                 480                    3        22.31          77.31               20.92        9.37
# ...

# %%
grades.corr()
# Out:
#                            age  study_hours  self_study_hours  \
# age                   1.000000     0.000511          0.004889
# study_hours           0.000511     1.000000         -0.003942
# self_study_hours      0.004889    -0.003942          1.000000
# online_classes_hours -0.001553     0.011238         -0.010100
# sleep_hours           0.004719    -0.027995         -0.007138
# screen_time_hours     0.001662    -0.022899         -0.016264
# caffeine_intake_mg    0.000437    -0.015362          0.007317
# mental_health_score  -0.023883    -0.013122          0.011482
# focus_index          -0.018509     0.448050          0.237721
# burnout_level        -0.013559    -0.000811          0.002670
# productivity_score   -0.013607     0.637981          0.057781
# exam_score           -0.009047     0.513434          0.083602
#
#                       online_classes_hours  sleep_hours  screen_time_hours  \
# age                              -0.001553     0.004719           0.001662
# ...

# %%
# What I plan to observe is how various factors such as study hours, sleep hours, etc affects the grades of students.
# From the above, only focusing on exam_score, comparing with the other columns, I can see that productivity_score has the highest positive correlation with exam_score at 0.886. This indicates that as productivity_score increase, exam_score tends to increase as well. Some other factors to note are focus_index. (They are factors that are above 0.6 correlation with exam_score)
# There are no obvious negative correlations with exam_score, however, screen_time_hours and caffeine_intake have negative correlations (though it is not a strong correlation therefore there is no reason to believe that they are significant factor affecting exam scores.)

#Now I shall visualize these correlations using scatter plots to better understand the relationships between exam_score and the other significant factors.
import matplotlib.pyplot as plt
grades.plot.scatter(x='exam_score', y='productivity_score', title='Productivity Score vs Exam Score')
# Out:
# <Axes: title={'center': 'Productivity Score vs Exam Score'}, xlabel='exam_score', ylabel='productivity_score'>

# %%
grades.head(500).plot.scatter(x='exam_score', y='productivity_score', title='Productivity Score vs Exam Score [First 500 Records]')
grades.tail(500).plot.scatter(x='exam_score', y='productivity_score', title='Productivity Score vs Exam Score [Last 500 Records]')
# Out:
# <Axes: title={'center': 'Productivity Score vs Exam Score [Last 500 Records]'}, xlabel='exam_score', ylabel='productivity_score'>

# %%
grades.plot.scatter(x='exam_score', y='focus_index', title='Focus Index vs Exam Score')
# Out:
# <Axes: title={'center': 'Focus Index vs Exam Score'}, xlabel='exam_score', ylabel='focus_index'>

# %%
grades.head(500).plot.scatter(x='exam_score', y='focus_index', title='Focus Index vs Exam Score [First 500 Records]')
grades.tail(500).plot.scatter(x='exam_score', y='focus_index', title='Focus Index vs Exam Score [Last 500 Records]')
# Out:
# <Axes: title={'center': 'Focus Index vs Exam Score [Last 500 Records]'}, xlabel='exam_score', ylabel='focus_index'>
